# %% [markdown]
# ### Ветвления. Анализ попадания точки с заданной координатой в область

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x, y = float(input()), float(input())
r = float(input())
if x ** 2 + y ** 2 > r ** 2:
    print('in')
elif x ** 2 + y ** 2 < r ** 2:
    print('out')
else:
    print('bound')

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import random

x, y = map(int, input().split())
if 2 < x < 9 and 1 < y < 4:
    print('in')
elif y == 1 and 2 <= x <= 9 or y == 4 and 2 <= x <= 9:
    print('bound')
elif x == 2 and 1 <= y <= 4 or x == 9 and 1 <= y <= 4:
    print('bound')
else:
    print('out')
# Out:
# bound

# %%
import random

x, y = map(int, input().split())
if 2 < x < 9 and 1 < y < 4:
    print('in')
elif (y == 1 or y == 4) and 2 <= x <= 9:
    print('bound')
elif (x == 2 or x == 9) and 1 <= y <= 4:
    print('bound')
else:
    print('out')
# Out:
# bound

# %%
x, y = map(int, input().split())
if 2 < x < 9 and 1 < y < 4:
    print('in')
elif (y == 1 or y == 4) and 2 <= x <= 9 or (x == 2 or x == 9) and 1 <= y <= 4:
    print('bound')
else:
    print('out')
# Out:
# bound

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x, y = map(int, input().split())
if 2 < x < 9 and 1 < y < 4:
    print('in')
elif x < 2 or x > 10 or y < 1 or y > 4:
    print('out')
else:
    print('bound')
# Out:
# bound

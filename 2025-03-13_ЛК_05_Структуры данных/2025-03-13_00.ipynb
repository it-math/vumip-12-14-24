# %% [markdown]
# # Структуры данных в Python

# %% [markdown]
# Python — объектно-ориентированный язык программирования, его основу составляют объекты и классы.
#
# Объект —  это область памяти компьютера, которая описывается типом (он же класс) и значением.
# При этом от типа зависит область значений объекта, операции и методы, которые к нему можно применять.

# %% [markdown]
# Python предоставляет богатый набор встроенных типов данных.

# %% [markdown]
# Python — язык программирования со строгой динамической типизацией.

# %% [markdown]
# Переменные в Python — это всего лишь указатели на объекты, они не содержат информации о типе.

# %% [markdown]
# ### Индексируемые структуры данных: строки, кортежи, списки
#
# В Python помимо базовых типов, которые соответствуют отдельным значениям
# * **int** – целые числа,
# * **float** – вещественные числа,
# * **bool** – булевы значения **True** и **False**,
#
# существуют типы, которые хранят последовательности значений.
#
# Последовательности значений могут быть индексируемыми и неиндексируемыми.
#
# В первом случае предполагается возможность выбора элемента последовательности по его порядковому номеру,
# плюс, допускается сортировка элементов, во втором случае обе эти операции не определены.
#
# К индексируемым (упорядоченным) структурам относятся:
#
# * тип **str**: строка (от *string*);
# * тип **tuple**: кортеж;
# * тип **list**: список.
#
# К неиндексируемым (неупорядоченным) структурам относятся:
#
# * тип **set**: множество;
# * тип **dict**: словарь (от *dictionary*).
#
# Рассмотрим индексируемые типы поподробнее.

# %% [markdown]
# ### Типы данных в Python можно разделить на изменяемые и неизменяемые.

# %% [markdown]
#  При присвоении нового значения неизменяемому объекту, Python не перезаписывает его, а создаёт новый объект с тем же именем.
#
#  Чтобы в этом убедиться, достаточно проверить id — уникальный номер, который присваивается каждому объекту в Python:

# %%
a = 10
print(a, id(a))
a = 11
print(a, id(a))
a += 10
print(a, id(a))
# Out:
# 10 140736616340184
# 11 140736616340216
# 21 140736616340536

# %% [markdown]
# К неизменяемым объектам относятся
# * **числа**,
# * **строки**
# * **кортежи**,
#
# а к изменяемым
# * **списки**,
# * **словари**,
# * **множества**.
#
# Это свойство нужно учитывать при передаче объектов в функцию.

# %% [markdown]
# #### Типы данных в Python можно разделить на три группы:
# - Простые — числа и строки.
# - Коллекции — списки, кортежи, множества и словари.
# - Остальные — файлы, итераторы, сокеты, NaN.

# %% [markdown]
# В Python существуют четыре встроенные структуры данных: **список, кортеж, словарь и множество**.

# %% [markdown]
# В Python все является объектами, и любой объект можно присвоить переменной.

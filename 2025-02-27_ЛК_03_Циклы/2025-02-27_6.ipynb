# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![01.jpg](attachment:01.jpg)

# %%
s = 0
n = 7
for i in range(1,n+1):
    s += (-1)**(i + 1)/i/(i+1)/(i+2)
print(s)
# Out:
# 0.13710317460317462

# %%
s = 0
i = 1
while i <= 7:
    s += (-1)**(i + 1)/i/(i+1)/(i+2)
    i += 1
print(s)
# Out:
# 0.13710317460317462

# %% [markdown]
# ![02.jpg](attachment:02.jpg)

# %%
p = 1
for k in range(1,8):
    p *= (-1)**(k + 1) / k / (k + 1)
print(p)
# Out:
# -4.920949861426052e-09

# %%
p = 1
k = 1
while k <= 7:
    p *= (-1)**(k + 1) / k / (k + 1)
    k += 1
print(p)
# Out:
# -4.920949861426052e-09

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = 0
x = 2
for i in range(0, 11):
    for j in range(1, 6):
        s += x ** (i + j) / (2 * i + 2 * j)
print(s)
# Out:
# 4937.507536907537

# %%
s = 0
x = 2
for i in range(0, 11):
    j = 1
    while j <= 5:
        s += x ** (i + j) / (2 * i + 2 * j)
        j += 1
print(s)
# Out:
# 4937.507536907537

# %%
s = 0
x = 2
i = 0
while i <= 10:
    for j in range(1, 6):
        s += x ** (i + j) / (2 * i + 2 * j)
    i += 1
print(s)
# Out:
# 4937.507536907537

# %%
s = 0
x = 2
i = 0
while i <= 10:
    j = 1
    while j <= 5:
        s += x ** (i + j) / (2 * i + 2 * j)
        j += 1
    i += 1
print(s)
# Out:
# 4937.507536907537
